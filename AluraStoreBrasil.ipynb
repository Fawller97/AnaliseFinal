# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %%
loja.Produto.unique()
# Out:
# array(['Assistente virtual', 'Mesa de jantar', 'Jogo de tabuleiro',
#        'Micro-ondas', 'Cadeira de escritório', 'Blocos de montar',
#        'Boneca bebê', 'Lava louças', 'Lavadora de roupas',
#        'Carrinho controle remoto', 'Geladeira', 'Fone de ouvido',
#        'Panela de pressão', 'Bicicleta', 'Ciência de dados com python',
#        'Bola de vôlei', 'Xadrez de madeira', 'TV Led UHD 4K',
#        'Copo térmico', 'Kit banquetas', 'Dashboards com Power BI',
#        'Faqueiro', 'Jogo de panelas', 'Bateria', 'Corda de pular',
#        'Fogão', 'Cama box', 'Impressora', 'Cômoda', 'Guarda roupas',
#        'Dinossauro Rex', 'Guitarra', 'Secadora de roupas',
#        'Sofá retrátil', 'Tablet ABXY', 'Cubo mágico 8x8', 'Jogo de copos',
#        'Modelagem preditiva', 'Celular Plus X42', 'Mochila',
#        'Bola de basquete', 'Headset', 'Poltrona', 'Violão',
#        'Iniciando em programação', 'Celular ABXY', 'Smartwatch',
# ...

# %%
nao_prod = ['Iniciando em programação', 'Ciência de dados com python', 'Assistente virtual', 'Dashboards com Power BI', 'Modelagem preditiva']
loja1_fin = loja.query('@nao_prod not in Produto')
loja1_fin
# Out:
#                     Produto Categoria do Produto    Preço      Frete  \
# 1            Mesa de jantar               moveis   256.35  11.234305
# 2         Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3               Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4     Cadeira de escritório               moveis   446.99  26.964689
# 5          Blocos de montar           brinquedos    32.26   0.000000
# ...                     ...                  ...      ...        ...
# 2354       Celular Plus X42          eletronicos  1712.54  88.772042
# 2355             Impressora          eletronicos   377.02  20.363958
# 2356      Jogo de tabuleiro           brinquedos   163.82   9.611337
# 2357               Cama box               moveis   921.77  46.665919
# 2358             Smartwatch          eletronicos   259.95  11.425995
#
#      Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
loja2.head()
# Out:
#                  Produto   Categoria do Produto    Preço      Frete  \
# 0  Cadeira de escritório                 moveis   378.20  20.421138
# 1               Pandeiro  instrumentos musicais   102.37   3.035334
# 2              Cama king                 moveis   591.13  31.759020
# 3              Cama king                 moveis  1208.24  61.919584
# 4  Cadeira de escritório                 moveis   530.41  25.827176
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     04/08/2021    Thiago Silva              MG                    1
# 1     26/11/2020   Bianca Santos              RJ                    3
# 2     22/10/2021    Thiago Silva              SC                    5
# 3     04/05/2022   Larissa Alves              RS                    5
# 4     26/02/2022  Lucas Oliveira              SP                    4
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0            boleto                       1 -18.10 -44.38
# ...

# %%
loja2.Produto.unique()
# Out:
# array(['Cadeira de escritório', 'Pandeiro', 'Cama king', 'Violão',
#        'Mochila', 'Tablet ABXY', 'Panela de pressão', 'Cubo mágico 8x8',
#        'Secadora de roupas', 'Jogo de tabuleiro', 'Xadrez de madeira',
#        'Bicicleta', 'Modelagem preditiva', 'Dashboards com Power BI',
#        'Corda de pular', 'Jogo de copos', 'Boneca bebê',
#        'Ciência de dados com python', 'Lava louças', 'Blocos de montar',
#        'Copo térmico', 'Faqueiro', 'Fogão', 'Jogo de panelas',
#        'TV Led UHD 4K', 'Poltrona', 'Guitarra', 'Headset',
#        'Dinossauro Rex', 'Smart TV', 'Guarda roupas', 'Geladeira',
#        'Mesa de centro', 'Lavadora de roupas', 'Bateria', 'Celular ABXY',
#        'Bola de basquete', 'Mesa de jantar', 'Kit banquetas', 'Cama box',
#        'Bola de vôlei', 'Assistente virtual', 'Sofá retrátil',
#        'Carrinho controle remoto', 'Fone de ouvido', 'Micro-ondas',
#        'Smartwatch', 'Iniciando em programação', 'Cômoda', 'Impressora',
# ...

# %%
nao_prod = ['Iniciando em programação', 'Ciência de dados com python', 'Assistente virtual', 'Dashboards com Power BI', 'Modelagem preditiva']
loja2_fin = loja2.query('@nao_prod not in Produto')
loja2_fin
# Out:
#                     Produto   Categoria do Produto    Preço       Frete  \
# 0     Cadeira de escritório                 moveis   378.20   20.421138
# 1                  Pandeiro  instrumentos musicais   102.37    3.035334
# 2                 Cama king                 moveis   591.13   31.759020
# 3                 Cama king                 moveis  1208.24   61.919584
# 4     Cadeira de escritório                 moveis   530.41   25.827176
# ...                     ...                    ...      ...         ...
# 2354        Jogo de panelas  utilidades domesticas   187.01   10.846135
# 2355     Lavadora de roupas       eletrodomesticos  1626.85   86.907994
# 2356            Micro-ondas       eletrodomesticos  1063.85   57.177917
# 2357       Celular Plus X42            eletronicos  2965.72  155.500107
# 2358              Bicicleta        esporte e lazer   734.62   36.700744
#
#      Data da Compra          Vendedor Local da compra  Avaliação da compra  \
# ...

# %%
loja3.Produto.unique()
# Out:
# array(['Secadora de roupas', 'Cômoda', 'Violão', 'Bola de vôlei',
#        'Guarda roupas', 'Impressora', 'Carrinho controle remoto',
#        'Cadeira de escritório', 'Pandeiro', 'Faqueiro', 'Boneca bebê',
#        'Fone de ouvido', 'Jogo de copos', 'TV Led UHD 4K',
#        'Panela de pressão', 'Lavadora de roupas', 'Jogo de panelas',
#        'Dinossauro Rex', 'Modelagem preditiva', 'Mesa de jantar',
#        'Dashboards com Power BI', 'Kit banquetas', 'Corda de pular',
#        'Iniciando em programação', 'Bola de basquete', 'Fogão',
#        'Bicicleta', 'Lava louças', 'Smart TV', 'Mochila', 'Tablet ABXY',
#        'Mesa de centro', 'Cama box', 'Xadrez de madeira',
#        'Celular Plus X42', 'Cama king', 'Smartwatch',
#        'Ciência de dados com python', 'Geladeira', 'Headset',
#        'Jogo de tabuleiro', 'Bateria', 'Guitarra', 'Sofá retrátil',
#        'Poltrona', 'Assistente virtual', 'Copo térmico', 'Celular ABXY',
# ...

# %%
nao_prod = ['Iniciando em programação', 'Ciência de dados com python', 'Assistente virtual', 'Dashboards com Power BI', 'Modelagem preditiva']
loja3_fin = loja3.query('@nao_prod not in Produto')
loja3_fin
# Out:
#                     Produto   Categoria do Produto    Preço       Frete  \
# 0        Secadora de roupas       eletrodomesticos  1713.50   88.823159
# 1                    Cômoda                 moveis   386.81   18.180908
# 2                    Violão  instrumentos musicais   404.62   23.197592
# 3             Bola de vôlei        esporte e lazer    78.40    4.463341
# 4             Guarda roupas                 moveis   694.76   34.578319
# ...                     ...                    ...      ...         ...
# 2351          Jogo de copos  utilidades domesticas    55.26    0.000000
# 2352             Smartwatch            eletronicos   262.55   11.564437
# 2353          TV Led UHD 4K            eletronicos  3438.14  191.148260
# 2356  Cadeira de escritório                 moveis   636.10   34.159188
# 2357         Mesa de centro                 moveis   164.15    6.324933
#
#      Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# ...

# %%
loja3_fin.head()
# Out:
#               Produto   Categoria do Produto    Preço      Frete  \
# 0  Secadora de roupas       eletrodomesticos  1713.50  88.823159
# 1              Cômoda                 moveis   386.81  18.180908
# 2              Violão  instrumentos musicais   404.62  23.197592
# 3       Bola de vôlei        esporte e lazer    78.40   4.463341
# 4       Guarda roupas                 moveis   694.76  34.578319
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     17/12/2021  Camila Ribeiro              CE                    4
# 1     10/02/2021   Larissa Alves              RS                    3
# 2     22/01/2023  Lucas Oliveira              SP                    5
# 3     22/03/2022     Pedro Gomes              BA                    4
# 4     12/01/2022   Bianca Santos              SP                    1
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       4  -5.20 -39.53
# ...

# %%
loja4.head()
# Out:
#                Produto Categoria do Produto    Preço      Frete  \
# 0          Lava louças     eletrodomesticos  1446.46  74.604083
# 1             Cama box               moveis   631.70  33.919251
# 2     Bola de basquete      esporte e lazer    31.54   0.000000
# 3  Modelagem preditiva               livros    76.93   1.680730
# 4       Fone de ouvido          eletronicos   185.14   7.442587
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     11/11/2022    Rafael Costa              SP                    4
# 1     03/01/2020    Thiago Silva              GO                    5
# 2     25/12/2022   Larissa Alves              MG                    5
# 3     23/11/2021  Lucas Oliveira              MG                    3
# 4     25/04/2022   Bianca Santos              SP                    4
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       3 -22.19 -48.79
# ...

# %%
loja4.Produto.unique()
# Out:
# array(['Lava louças', 'Cama box', 'Bola de basquete',
#        'Modelagem preditiva', 'Fone de ouvido', 'Geladeira', 'Guitarra',
#        'Headset', 'Celular Plus X42', 'Cômoda', 'Boneca bebê',
#        'Dashboards com Power BI', 'Cadeira de escritório',
#        'Kit banquetas', 'Impressora', 'Jogo de copos', 'Mesa de jantar',
#        'Carrinho controle remoto', 'Corda de pular', 'Fogão', 'Cama king',
#        'Bola de vôlei', 'Secadora de roupas', 'Dinossauro Rex',
#        'TV Led UHD 4K', 'Copo térmico', 'Smart TV', 'Mesa de centro',
#        'Tablet ABXY', 'Panela de pressão', 'Bateria', 'Pandeiro',
#        'Iniciando em programação', 'Jogo de tabuleiro', 'Celular ABXY',
#        'Faqueiro', 'Guarda roupas', 'Blocos de montar', 'Bicicleta',
#        'Assistente virtual', 'Jogo de panelas', 'Violão',
#        'Xadrez de madeira', 'Micro-ondas', 'Smartwatch', 'Mochila',
#        'Lavadora de roupas', 'Ciência de dados com python',
# ...

# %%
nao_prod = ['Iniciando em programação', 'Ciência de dados com python', 'Assistente virtual', 'Dashboards com Power BI', 'Modelagem preditiva']
loja4_fin = loja4.query('@nao_prod not in Produto')
loja4_fin
# Out:
#                     Produto   Categoria do Produto    Preço       Frete  \
# 0               Lava louças       eletrodomesticos  1446.46   74.604083
# 1                  Cama box                 moveis   631.70   33.919251
# 2          Bola de basquete        esporte e lazer    31.54    0.000000
# 4            Fone de ouvido            eletronicos   185.14    7.442587
# 5                 Geladeira       eletrodomesticos  2122.48  110.600114
# ...                     ...                    ...      ...         ...
# 2353         Mesa de jantar                 moveis   303.60   16.852799
# 2354  Cadeira de escritório                 moveis   456.02   24.812798
# 2355           Copo térmico        esporte e lazer    48.99    3.139675
# 2356        Jogo de panelas  utilidades domesticas   202.45   11.062979
# 2357         Corda de pular        esporte e lazer    14.89    1.732696
#
#      Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# ...

# %%
faturamento = loja1_fin['Preço'].sum()
faturamento2 = loja2_fin['Preço'].sum()
faturamento3 = loja3_fin['Preço'].sum()
faturamento4 = loja4_fin['Preço'].sum()

# %%
print(f"A Primeira loja faturou R${faturamento}")
print(f"A Segunda loja faturou R${faturamento2}")
print(f"A Terceira loja faturou R${faturamento3}")
print(f"A Quarta loja faturou R$ {faturamento4}")
# Out:
# A Primeira loja faturou R$1512051.15
# A Segunda loja faturou R$1464432.2399999998
# A Terceira loja faturou R$1440676.27
# A Quarta loja faturou R$ 1358113.8

# %% [markdown]
# # 2. Vendas por Categoria

# %%
popular_1 = loja1_fin['Categoria do Produto'].value_counts()
popular_2 = loja2_fin['Categoria do Produto'].value_counts()
popular_3 = loja3_fin['Categoria do Produto'].value_counts()
popular_4 = loja4_fin['Categoria do Produto'].value_counts()

# %%
popular_1
# Out:
# Categoria do Produto
# moveis                   465
# eletronicos              408
# brinquedos               324
# eletrodomesticos         312
# esporte e lazer          284
# instrumentos musicais    182
# utilidades domesticas    171
# Name: count, dtype: int64

# %%
popular_2
# Out:
# Categoria do Produto
# moveis                   442
# eletronicos              384
# brinquedos               313
# eletrodomesticos         305
# esporte e lazer          275
# instrumentos musicais    224
# utilidades domesticas    181
# Name: count, dtype: int64

# %%
popular_3
# Out:
# Categoria do Produto
# moveis                   499
# eletronicos              412
# brinquedos               315
# eletrodomesticos         278
# esporte e lazer          277
# instrumentos musicais    177
# utilidades domesticas    177
# Name: count, dtype: int64

# %%
popular_4
# Out:
# Categoria do Produto
# moveis                   480
# eletronicos              401
# brinquedos               338
# esporte e lazer          277
# eletrodomesticos         254
# utilidades domesticas    201
# instrumentos musicais    170
# Name: count, dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

print(f"A Primeira loja teve o maior volume de vendas em {popular_1.index[0]} com um total de {popular_1[0]} vendas")
print(f"A Segunda loja teve o maior volume de vendas em {popular_2.index[0]} com um total de {popular_2[0]} vendas ")
print(f"A Terceira loja teve o maior volume de vendas em {popular_3.index[0]} com um total de {popular_3[0]} vendas ")
print(f"A Quarta loja teve o maior volume de vendas em {popular_4.index[0]} com um total de {popular_4[0]} vendas ")
# Out:
# A Primeira loja teve o maior volume de vendas em moveis com um total de 465 vendas
# A Segunda loja teve o maior volume de vendas em moveis com um total de 442 vendas
# A Terceira loja teve o maior volume de vendas em moveis com um total de 499 vendas
# A Quarta loja teve o maior volume de vendas em moveis com um total de 480 vendas

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
med_aval_1 =loja1_fin['Avaliação da compra'].mean()
med_aval_1 = round(med_aval_1, 2)


med_aval_2 =loja2_fin['Avaliação da compra'].mean()
med_aval_2 = round(med_aval_2, 2)


med_aval_3 =loja3_fin['Avaliação da compra'].mean()
med_aval_3 = round(med_aval_3, 2)


med_aval_4 =loja4_fin['Avaliação da compra'].mean()
med_aval_4 = round(med_aval_4, 2)

# %%
print(f"A pesquisa de satisfação indica as seguintes notas: loja 1: {med_aval_1}" + f" - loja 2: {med_aval_2}" + f" - loja 3: {med_aval_3}" + f" - loja 4: {med_aval_4}")
# Out:
# A pesquisa de satisfação indica as seguintes notas: loja 1: 3.97 - loja 2: 4.05 - loja 3: 4.05 - loja 4: 3.99

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
popular_1 = loja1_fin['Produto'].value_counts()
popular_2 = loja2_fin['Produto'].value_counts()
popular_3 = loja3_fin['Produto'].value_counts()
popular_4 = loja4_fin['Produto'].value_counts()

# %%
maisVend_loja1 = popular_1.head(5) 
menosVend_loja1 = popular_1.tail(5)
maisVend_loja2 = popular_2.head(5) 
menosVend_loja2 = popular_2.tail(5)
maisVend_loja3 = popular_3.head(5) 
menosVend_loja3 = popular_3.tail(5)
maisVend_loja4 = popular_4.head(5) 
menosVend_loja4 = popular_4.tail(5)

# %%
print(f'Os produtos mais vendidos da loja 1 foram: {maisVend_loja1}')
print(f'Os produtos mais vendidos da loja 2 foram: {maisVend_loja2}')
print(f'Os produtos mais vendidos da loja 3 foram: {maisVend_loja3}')
print(f'Os produtos mais vendidos da loja 4 foram: {maisVend_loja4}')
# Out:
# Os produtos mais vendidos da loja 1 foram: Produto
# Micro-ondas           60
# TV Led UHD 4K         60
# Guarda roupas         60
# Secadora de roupas    58
# Cômoda                56
# Name: count, dtype: int64
# Os produtos mais vendidos da loja 2 foram: Produto
# Micro-ondas           62
# Bateria               61
# Pandeiro              58
# Violão                58
# Secadora de roupas    57
# Name: count, dtype: int64
# Os produtos mais vendidos da loja 3 foram: Produto
# Kit banquetas      57
# Mesa de jantar     56
# Cama king          56
# Jogo de panelas    55
# Cômoda             55
# Name: count, dtype: int64
# Os produtos mais vendidos da loja 4 foram: Produto
# Cama box                    62
# Faqueiro                    59
# Cama king                   56
# Carrinho controle remoto    55
# Mesa de jantar              55
# Name: count, dtype: int64

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
med_Frete_1 =loja1_fin['Frete'].mean()
med_Frete_1 = round(med_Frete_1, 2)
med_Frete_2 =loja2_fin['Frete'].mean()
med_Frete_2 = round(med_Frete_2, 2)
med_Frete_3 =loja3_fin['Frete'].mean()
med_Frete_3 = round(med_Frete_3, 2)
med_Frete_4 =loja4_fin['Frete'].mean()
med_Frete_4 = round(med_Frete_4, 2)

# %%
print('Segue a baixo a média dos valores de frete de cada loja'f'\nA loja 1 tem uma média de {med_Frete_1}' f'\nA loja 2 tem uma média de {med_Frete_2}' f'\nA loja 3 tem uma média de {med_Frete_3}' f'\nA loja 4 tem uma média de {med_Frete_4}')
# Out:
# Segue a baixo a média dos valores de frete de cada loja
# A loja 1 tem uma média de 37.58
# A loja 2 tem uma média de 36.73
# A loja 3 tem uma média de 35.97
# A loja 4 tem uma média de 34.08
