# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# 1    cartao_credito                       4 -22.25 -42.66
# 2    cartao_credito                       1 -15.83 -47.86
# 3            boleto                       1 -30.17 -53.50
# 4            boleto                       1 -18.10 -44.38

# %% [markdown]
# #1. Análise do faturamento

# %%
loja2.head()
# Out:
#                  Produto   Categoria do Produto    Preço      Frete  \
# 0  Cadeira de escritório                 moveis   378.20  20.421138
# 1               Pandeiro  instrumentos musicais   102.37   3.035334
# 2              Cama king                 moveis   591.13  31.759020
# 3              Cama king                 moveis  1208.24  61.919584
# 4  Cadeira de escritório                 moveis   530.41  25.827176
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     04/08/2021    Thiago Silva              MG                    1
# 1     26/11/2020   Bianca Santos              RJ                    3
# 2     22/10/2021    Thiago Silva              SC                    5
# 3     04/05/2022   Larissa Alves              RS                    5
# 4     26/02/2022  Lucas Oliveira              SP                    4
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0            boleto                       1 -18.10 -44.38
# 1    cartao_credito                       4 -22.25 -42.66
# 2    cartao_credito                      10 -27.45 -50.95
# 3    cartao_credito                      10 -30.17 -53.50
# 4    cartao_credito                       3 -22.19 -48.79

# %%
loja3.head(30)
# Out:
#                      Produto   Categoria do Produto    Preço       Frete  \
# 0         Secadora de roupas       eletrodomesticos  1713.50   88.823159
# 1                     Cômoda                 moveis   386.81   18.180908
# 2                     Violão  instrumentos musicais   404.62   23.197592
# 3              Bola de vôlei        esporte e lazer    78.40    4.463341
# 4              Guarda roupas                 moveis   694.76   34.578319
# 5                 Impressora            eletronicos   307.64   13.965344
# 6   Carrinho controle remoto             brinquedos    74.26    4.237248
# 7      Cadeira de escritório                 moveis   619.44   33.514421
# 8                   Pandeiro  instrumentos musicais    58.01    3.619963
# 9                   Faqueiro  utilidades domesticas    44.73    0.000000
# 10               Boneca bebê             brinquedos    60.64    0.000000
# 11     Cadeira de escritório                 moveis   580.24   28.480473
# 12                Impressora            eletronicos   310.02   18.160427
# 13            Fone de ouvido            eletronicos    91.63    6.531816
# 14             Jogo de copos  utilidades domesticas    52.13    3.306870
# 15             TV Led UHD 4K            eletronicos  2053.75  106.940448
# 16         Panela de pressão  utilidades domesticas   111.28    3.509764
# 17         Panela de pressão  utilidades domesticas    92.34    5.443092
# 18               Boneca bebê             brinquedos    51.20    3.257350
# 19                    Cômoda                 moveis   335.28   15.437090
# 20        Lavadora de roupas       eletrodomesticos  2003.23  107.554386
# 21           Jogo de panelas  utilidades domesticas   170.82    9.378777
# 22            Dinossauro Rex             brinquedos    22.22    0.000000
# 23       Modelagem preditiva                 livros   102.08    6.323868
# 24         Panela de pressão  utilidades domesticas    87.53    4.949486
# 25            Mesa de jantar                 moveis   396.14   24.257080
# 26   Dashboards com Power BI                 livros    45.14    2.934674
# 27             Kit banquetas                 moveis   447.99   21.438559
# 28            Corda de pular        esporte e lazer    22.75    1.494495
# 29  Iniciando em programação                 livros    86.73    5.149216
#
#    Data da Compra          Vendedor Local da compra  Avaliação da compra  \
# 0      17/12/2021    Camila Ribeiro              CE                    4
# 1      10/02/2021     Larissa Alves              RS                    3
# 2      22/01/2023    Lucas Oliveira              SP                    5
# 3      22/03/2022       Pedro Gomes              BA                    4
# 4      12/01/2022     Bianca Santos              SP                    1
# 5      20/11/2022  Mariana Ferreira              MG                    5
# 6      07/07/2020   Bruno Rodrigues              SP                    2
# 7      01/05/2022  Isabella Pereira              SP                    5
# 8      27/10/2021     Larissa Alves              MG                    5
# 9      03/05/2022     Felipe Santos              RJ                    5
# 10     16/08/2021    Beatriz Moraes              PI                    5
# 11     25/09/2022     Felipe Santos              GO                    2
# 12     16/01/2023    Lucas Oliveira              MG                    5
# 13     31/01/2022        João Souza              RS                    4
# 14     08/11/2021        João Souza              CE                    5
# 15     04/02/2021      Rafael Costa              SP                    5
# 16     17/02/2022        João Souza              SP                    5
# 17     17/08/2022   Bruno Rodrigues              SP                    4
# 18     01/04/2021      Rafael Costa              SP                    5
# 19     01/10/2022    Beatriz Moraes              PE                    4
# 20     19/09/2022     Felipe Santos              DF                    1
# 21     29/08/2022      Thiago Silva              ES                    5
# 22     21/01/2020     Juliana Costa              RJ                    4
# 23     24/06/2022    Beatriz Moraes              SP                    5
# 24     21/08/2020      Thiago Silva              RJ                    1
# 25     05/11/2021    Lucas Oliveira              PA                    5
# 26     19/05/2021       Pedro Gomes              BA                    5
# 27     22/02/2023    Lucas Oliveira              DF                    4
# 28     21/08/2020    Beatriz Moraes              SP                    4
# 29     26/08/2022    Camila Ribeiro              SP                    1
#
#    Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0     cartao_credito                       4  -5.20 -39.53
# 1     cartao_credito                       1 -30.17 -53.50
# 2     cartao_credito                       3 -22.19 -48.79
# 3     cartao_credito                       6 -13.29 -41.71
# 4     cartao_credito                       1 -22.19 -48.79
# 5     cartao_credito                       5 -18.10 -44.38
# 6             boleto                       1 -22.19 -48.79
# 7             boleto                       1 -22.19 -48.79
# 8     cartao_credito                       3 -18.10 -44.38
# 9             boleto                       1 -22.25 -42.66
# 10            boleto                       1  -6.60 -42.28
# 11    cartao_credito                       1 -15.98 -49.86
# 12    cartao_credito                       2 -18.10 -44.38
# 13    cartao_credito                       1 -30.17 -53.50
# 14            boleto                       1  -5.20 -39.53
# 15    cartao_credito                       1 -22.19 -48.79
# 16            boleto                       1 -22.19 -48.79
# 17    cartao_credito                       1 -22.19 -48.79
# 18    cartao_credito                       1 -22.19 -48.79
# 19    cartao_credito                       3  -8.38 -37.86
# 20    cartao_credito                       8 -15.83 -47.86
# 21    cartao_credito                       4 -19.19 -40.34
# 22    cartao_credito                       1 -22.25 -42.66
# 23    cartao_credito                       1 -22.19 -48.79
# 24    cartao_credito                       1 -22.25 -42.66
# 25    cartao_credito                       3  -3.79 -52.48
# 26    cartao_credito                       1 -13.29 -41.71
# 27    cartao_credito                       1 -15.83 -47.86
# 28    cartao_credito                      10 -22.19 -48.79
# 29    cartao_credito                       5 -22.19 -48.79

# %%
loja4.head()
# Out:
#                Produto Categoria do Produto    Preço      Frete  \
# 0          Lava louças     eletrodomesticos  1446.46  74.604083
# 1             Cama box               moveis   631.70  33.919251
# 2     Bola de basquete      esporte e lazer    31.54   0.000000
# 3  Modelagem preditiva               livros    76.93   1.680730
# 4       Fone de ouvido          eletronicos   185.14   7.442587
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     11/11/2022    Rafael Costa              SP                    4
# 1     03/01/2020    Thiago Silva              GO                    5
# 2     25/12/2022   Larissa Alves              MG                    5
# 3     23/11/2021  Lucas Oliveira              MG                    3
# 4     25/04/2022   Bianca Santos              SP                    4
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       3 -22.19 -48.79
# 1    cartao_credito                       2 -15.98 -49.86
# 2            boleto                       1 -18.10 -44.38
# 3            boleto                       1 -18.10 -44.38
# 4    cartao_credito                       7 -22.19 -48.79

# %%
faturamento = loja['Preço'].sum()
faturamento2 = loja2['Preço'].sum()
faturamento3 = loja3['Preço'].sum()
faturamento4 = loja4['Preço'].sum()

# %%
print(f"A Primeira loja faturou R${faturamento}")
print(f"A Segunda loja faturou R${faturamento2}")
print(f"A Terceira loja faturou R${faturamento3}")
print(f"A Quarta loja faturou R$ {faturamento4}")
# Out:
# A Primeira loja faturou R$1534509.12
# A Segunda loja faturou R$1488459.06
# A Terceira loja faturou R$1464025.03
# A Quarta loja faturou R$ 1384497.58

# %% [markdown]
# # 2. Vendas por Categoria

# %%
popular_1 = loja['Categoria do Produto'].value_counts()
popular_2 = loja2['Categoria do Produto'].value_counts()
popular_3 = loja3['Categoria do Produto'].value_counts()
popular_4 = loja4['Categoria do Produto'].value_counts()

# %%
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

print(f"A Primeira loja teve o maior volume de vendas em {popular_1.index[0]} com um total de {popular_1[0]} vendas")
print(f"A Segunda loja teve o maior volume de vendas em {popular_2.index[0]} com um total de {popular_2[0]} vendas ")
print(f"A Terceira loja teve o maior volume de vendas em {popular_3.index[0]} com um total de {popular_3[0]} vendas ")
print(f"A Quarta loja teve o maior volume de vendas em {popular_4.index[0]} com um total de {popular_4[0]} vendas ")
# Out:
# A Primeira loja teve o maior volume de vendas em moveis com um total de 465 vendas
# A Segunda loja teve o maior volume de vendas em moveis com um total de 442 vendas
# A Terceira loja teve o maior volume de vendas em moveis com um total de 499 vendas
# A Quarta loja teve o maior volume de vendas em moveis com um total de 480 vendas

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %% [markdown]
# # 5. Frete Médio por Loja
